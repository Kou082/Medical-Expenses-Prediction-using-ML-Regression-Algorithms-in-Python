# %% [markdown]
# # Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.chdir(r"C:\Users\koushik\OneDrive\Desktop\ML Projects\Medical-+Code\Code")

# %%
medi = pd.read_csv("Medical cost.csv")
medi.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height,
# objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9

# %%
# Can you accurately predict insurance costs?

# %%
medi.shape
# Out:
# (1338, 7)

# %%
medi.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
medi.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
## Visualizing

# %%
medi[['sex','age']].groupby('sex').agg(['mean','count'])
# Out:
#               age
#              mean count
# sex
# female  39.503021   662
# male    38.917160   676

# %%
medi['smoker'].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
medi[['sex','children']].groupby('sex').agg(['mean'])
# Out:
#         children
#             mean
# sex
# female  1.074018
# male    1.115385

# %% [markdown]
# # Data Visualisation

# %%
fig=plt.figure(figsize=(15,8))
sns.pairplot(medi)
plt.show()
# Out:
# C:\Users\koushik\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\koushik\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\koushik\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
numerical_columns = medi.select_dtypes(include=['float64', 'int64'])

correlation_matrix = numerical_columns.corr()

# Creating the heatmap for numerical columns
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Columns')
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.scatterplot(data=medi, x="age", y="bmi", hue="sex", style="sex")
# Out:
# <Axes: xlabel='age', ylabel='bmi'>

# %%
# Barplot
fig=plt.figure(figsize=(15,5))
sns.barplot(data = medi , x = "region" , y ='charges')
plt.show()

# %%
# Barplot
fig=plt.figure(figsize=(15,5))
sns.barplot(data = medi , x = "region" , y ='charges')
plt.show()

# %%
average_bmi_by_region = medi.groupby('region')['bmi'].mean().reset_index()

# Creating the bar plot
plt.figure(figsize=(15, 5))
sns.barplot(data=average_bmi_by_region, x='region', y='bmi')
plt.xlabel('Region')
plt.ylabel('Average BMI')
plt.title('Average BMI by Region')
plt.show()

# %%
max_rev = medi.groupby(['region','sex'])['charges'].mean()
max_rev = pd.DataFrame(max_rev)
max_rev = max_rev.reset_index()

fig=plt.figure(figsize=(15,7))
sns.barplot(x = max_rev.region , y = max_rev.charges,hue= max_rev.sex)
plt.show()
#max_rev

# %%
max_rev = medi.groupby(['region','smoker'])['charges'].mean()
max_rev = pd.DataFrame(max_rev)
max_rev = max_rev.reset_index()

fig=plt.figure(figsize=(15,7))
sns.barplot(x = max_rev.region , y = max_rev.charges,hue= max_rev.smoker)
plt.show()
#max_rev

# %%
max_rev = medi.groupby(['region','sex'])['age'].mean()
max_rev = pd.DataFrame(max_rev)
max_rev = max_rev.reset_index()

fig=plt.figure(figsize=(15,7))
sns.barplot(x = max_rev.region , y = max_rev.age,hue= max_rev.sex)
plt.show()
#max_rev

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=medi, x="age", y="age", hue="sex", style="sex")
# Out:
# <Axes: xlabel='age', ylabel='age'>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=medi, x="age", y="charges", hue="smoker", style="smoker")
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
# Understanding about some columns first.

sns.set_theme(style="whitegrid")
sns.boxplot(medi['charges'])
# Out:
# <Axes: >

# %%
sns.boxplot(medi['bmi'])
# Out:
# <Axes: >

# %%
sns.boxplot(medi['age'])
# Out:
# <Axes: >

# %%
# First removing outlier values:

medi = medi[medi['bmi'] < 47]
# medi = medi[medi['charges'] < 25000]

medi.shape
# Out:
# (1329, 7)

# %%
# Finding categorical data:

medi['smoker'].value_counts()
# Out:
# smoker
# no     1058
# yes     271
# Name: count, dtype: int64

# %%
medi['region'].value_counts()
# Out:
# region
# southeast    357
# northwest    325
# southwest    324
# northeast    323
# Name: count, dtype: int64

# %% [markdown]
# # One Hot Encoding the Categorical Variables

# %%
medi['sex'].value_counts()
# Out:
# sex
# male      670
# female    659
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

def label_encoded(feat):
    le = LabelEncoder()
    le.fit(feat)
    print(feat.name,le.classes_)
    return le.transform(feat)

# %%
name_list = ['sex', 'smoker', 'region']

for name in name_list:
  medi[name] = label_encoded(medi[name])

medi.head(3)
# Out:
# sex ['female' 'male']
# smoker ['no' 'yes']
# region ['northeast' 'northwest' 'southeast' 'southwest']
#    age  sex    bmi  children  smoker  region     charges
# 0   19    0  27.90         0       1       3  16884.9240
# 1   18    1  33.77         1       0       2   1725.5523
# 2   28    1  33.00         3       0       2   4449.4620

# %% [markdown]
# # Making Independent and Dependent Variables

# %%
y = medi['charges']
X = medi.drop(['charges'], axis = 1)

# %% [markdown]
# # Splitting Dataset into Training and Test Set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

# %% [markdown]
# # Applying Different Regression ML Model

# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# ## Building Multiple Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting Test Set Results

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([ -176.83496622,  6882.83648458, 30969.27086099, 37019.30464916,
#         9145.28121952, 29878.08015766, 14558.28210732, 16816.80543929,
#        10492.65722822, 11542.38512267, 36781.95670371, 14429.46536719,
#        31057.65818204, 11112.49313138,  6343.59777075, 28087.089219  ,
#        11681.34172112,  6057.62264842, 14849.84602091, 32464.90923367,
#        27748.4955239 ,  -226.64183093,  2445.79249497,  3649.74639256,
#         3956.66466744, 13459.05120721,  1194.97825698,  1602.38289683,
#        16552.85347178,  5652.82831594, 14504.15011589,  9061.75988984,
#        19350.0030325 , 39359.1477171 ,  9900.02542984, -1716.99922552,
#         4443.03128316, 37893.34213068,  6187.91628012,  5299.58952953,
#        14460.98652717, 36115.93320286, 15096.61931155, 12651.44313373,
#        11643.11574617, 11865.55591389, 26283.53103387,  3202.9548268 ,
#        38379.35297793,  9154.36129814,  6033.42341744, 12325.70797673,
# ...

# %% [markdown]
# ## Evaluating the Model Accuracy (R Square and Adjusted R Square)

# %%
from sklearn.metrics import r2_score
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Calculating R-squared and adjusted R-squared
r_squared = r2_score(y_test, y_pred)
n = len(y_test)
k = X.shape[1]  
adjusted_r_squared = 1 - (1 - r_squared) * (n - 1) / (n - k - 1)
print(f"R-squared : {r_squared}")
print(f"Adjusted R-squared: {adjusted_r_squared}")
# Out:
# R-squared : 0.7055912061161285
# Adjusted R-squared: 0.6987709251767338

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Training the Polynomial Regression Model on the Whole Dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
pol_reg = PolynomialFeatures(degree = 4)
x_poly = pol_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Evaluating the Model Accuracy (R Square and Adjusted R Square)

# %%
y_pred = lin_reg_2.predict(x_poly)

lin_reg_2.score(x_poly, y)

from sklearn.metrics import r2_score
r_squared = r2_score(y, y_pred)

n = x_poly.shape[0]
p = x_poly.shape[1]

adjusted_r_squared = 1 - (1 - r_squared) * (n - 1) / (n - p - 1)

# %%
print(f"R Squared : {r_squared}")
print(f"Adjusted R Squared : {adjusted_r_squared}")
# Out:
# R Squared : 0.8345753101210502
# Adjusted R Squared : 0.8035026939541634

# %% [markdown]
# # Support Vector Regression

# %% [markdown]
# ## Training the SVR Model on the Whole Dataset

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, y_train)
# Out:
# SVR()

# %% [markdown]
# ## Predicting Test Set Results

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([8801.41523762, 8909.79342563, 8924.81753006, 9008.61905127,
#        8991.19873124, 8922.949639  , 9047.37816196, 9052.49004254,
#        9011.72631434, 8883.07635392, 9042.50684925, 9014.1811121 ,
#        8864.23167103, 9012.4016119 , 8915.28075737, 8861.23754385,
#        9007.75038952, 8837.33794868, 9050.91862519, 8967.59977269,
#        8813.63809002, 8814.29598834, 8801.88305991, 8848.37840155,
#        8836.85527791, 9013.50553582, 8793.95370811, 8828.46254603,
#        9044.25487462, 8848.59316076, 9007.06825564, 8909.8758777 ,
#        9046.18624939, 9029.66809127, 8973.50271495, 8801.12335385,
#        8821.86705009, 8969.84201479, 8827.13433881, 8819.39095079,
#        8989.82394818, 8888.78463349, 9034.3589731 , 8995.92476344,
#        8995.59516933, 9018.3377781 , 8803.13402651, 8805.19899841,
#        8989.92237165, 8946.27999428, 8832.00114424, 8969.37070976,
#        8962.91038359, 8947.60952797, 8868.22966983, 8940.25141396,
# ...

# %% [markdown]
# ## Evaluating the Model Accuracy (R Square and Adjusted R Square)

# %%
from sklearn.metrics import r2_score

r_squared = r2_score(y_test, y_pred)
n = len(y_test)
k = X.shape[1]  # Number of predictors excluding the intercept
adjusted_r_squared = 1 - (1 - r_squared) * (n - 1) / (n - k - 1)

print(f"R-squared: {r_squared:.3f}")
print(f"Adjusted R-squared: {adjusted_r_squared:.3f}")
# Out:
# R-squared: -0.205
# Adjusted R-squared: -0.233

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
random_model = RandomForestRegressor(n_estimators=300, random_state = 0, n_jobs = -1)

# %% [markdown]
# ## Predicting Results on the Test Set

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([8801.41523762, 8909.79342563, 8924.81753006, 9008.61905127,
#        8991.19873124, 8922.949639  , 9047.37816196, 9052.49004254,
#        9011.72631434, 8883.07635392, 9042.50684925, 9014.1811121 ,
#        8864.23167103, 9012.4016119 , 8915.28075737, 8861.23754385,
#        9007.75038952, 8837.33794868, 9050.91862519, 8967.59977269,
#        8813.63809002, 8814.29598834, 8801.88305991, 8848.37840155,
#        8836.85527791, 9013.50553582, 8793.95370811, 8828.46254603,
#        9044.25487462, 8848.59316076, 9007.06825564, 8909.8758777 ,
#        9046.18624939, 9029.66809127, 8973.50271495, 8801.12335385,
#        8821.86705009, 8969.84201479, 8827.13433881, 8819.39095079,
#        8989.82394818, 8888.78463349, 9034.3589731 , 8995.92476344,
#        8995.59516933, 9018.3377781 , 8803.13402651, 8805.19899841,
#        8989.92237165, 8946.27999428, 8832.00114424, 8969.37070976,
#        8962.91038359, 8947.60952797, 8868.22966983, 8940.25141396,
# ...

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
decision_tree = DecisionTreeRegressor(random_state=0)
decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = decision_tree.predict(X_test)

# %%
y_pred
# Out:
# array([ 1980.07   ,  5920.1041 , 32787.45859, 43254.41795, 27117.99378,
#        21259.37795, 13880.949  , 14410.9321 , 11073.176  ,  5124.1887 ,
#        29523.1656 , 12363.547  , 37270.1512 , 10796.35025,  7228.21565,
#        17496.306  , 24476.47851, 20177.67113, 13555.0049 , 25309.489  ,
#        33475.81715,  2045.68525,  1967.0227 ,  3757.8448 ,  2689.4954 ,
#        10601.412  ,  2196.4732 ,  3176.2877 , 13405.3903 ,  4239.89265,
#        10436.096  ,  7749.1564 , 15230.32405, 44641.1974 ,  9617.66245,
#         1242.26   ,  2721.3208 , 42983.4585 ,  4618.0799 ,  3201.24515,
#        10848.1343 , 58571.07448, 12244.531  , 12096.6512 , 10338.9316 ,
#        11658.11505, 16232.847  ,  1967.0227 , 44641.1974 ,  8520.026  ,
#         4564.19145,  9620.3307 , 41676.0811 ,  7348.142  , 37701.8768 ,
#         7727.2532 , 13844.7972 , 11837.16   , 43254.41795,  3861.20965,
#        12638.195  , 13352.0998 , 12479.70895, 13981.85035,  7623.518  ,
# ...

# %% [markdown]
# ## Determining the Value of R Square and Adjusted R Square

# %%
from sklearn.metrics import r2_score

r_squared = r2_score(y_test, y_pred)
n = len(y_test)
k = X.shape[1]  # Number of predictors excluding the intercept
adjusted_r_squared = 1 - (1 - r_squared) * (n - 1) / (n - k - 1)

print(f"R-squared: {r_squared:.3f}")
print(f"Adjusted R-squared: {adjusted_r_squared:.3f}")
# Out:
# R-squared: 0.728
# Adjusted R-squared: 0.722

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=10, random_state=0)
regressor.fit(X,y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %% [markdown]
# ## Predicting Test Set Results

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([ 1939.7718   ,  5970.85298  , 33265.322754 , 44560.189745 ,
#        11637.583316 , 22076.642882 , 15229.398368 , 14330.82964  ,
#        25483.444742 ,  5894.73375  , 29470.457359 , 13468.651056 ,
#        49887.208483 , 10691.9629   , 11887.095303 , 18502.210875 ,
#        13119.992977 , 10023.745355 , 13855.30928  , 26494.11388  ,
#        34115.31503  , 13944.859434 ,  3538.088151 ,  3799.71387  ,
#         4524.546097 , 16603.668526 ,  2687.2843019,  3320.883335 ,
#        13031.51477  ,  4302.56308  , 11567.686121 ,  7994.004855 ,
#        15413.06237  , 47706.317665 , 13514.923518 ,  1241.8291   ,
#         2874.122555 , 45326.589215 , 12091.270359 ,  2989.876745 ,
#        13533.587399 , 42464.598775 , 23063.199813 , 14442.915603 ,
#        20535.963768 , 11657.90377  , 17713.63078  ,  2216.37891  ,
#        46336.37848  ,  9418.858561 ,  5745.654754 ,  9587.27552  ,
#        42249.14324  ,  7423.731485 , 43893.003449 ,  7780.744255 ,
# ...

# %% [markdown]
# ## R Square and Adjusted R Square Value

# %%
from sklearn.metrics import r2_score

r_squared = r2_score(y_test, y_pred)
n = len(y_test)
k = X.shape[1]  # Number of predictors excluding the intercept
adjusted_r_squared = 1 - (1 - r_squared) * (n - 1) / (n - k - 1)

print(f"R-squared: {r_squared:.3f}")
print(f"Adjusted R-squared: {adjusted_r_squared:.3f}")
# Out:
# R-squared: 0.966
# Adjusted R-squared: 0.965

# %%
# Save the trained model as a pickle string.
import pickle 

saved_model = pickle.dump(regressor, open(r"C:\Users\koushik\OneDrive\Desktop\ML Projects\Medical-+Code\Code\mysite\polls\Medical.pickle",'wb'))
